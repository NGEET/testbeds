# %% [markdown]
# # Panama Traits Analysis for defining parameters for a FATES ensemble

# %% [markdown]
# #### First import various libraries

# %%
import pandas
import numpy as np
# import map_funcs
import sys
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('seaborn-ticks')
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5, "lines.markersize": 6.0, 'lines.markeredgewidth': 1.0})

# %% [markdown]
# #### Here we define some temperature scaling functions.  These will be used later to translate vcmax$_T$ to vcmax$_{25}$ values.

# %%
global tfrz
global rgas
tfrz = 273.15
rgas = 8314.4598

### temperature functions for scaling vcmax and jmax to temperatures
def ft1_f(tl, ha):
    # from FATES code
    # !
    # !!DESCRIPTION:
    # ! photosynthesis temperature response
    # !
    # ! !ARGUMENTS:
    # real(r8), intent(in) :: tl  ! leaf temperature in photosynthesis temperature function (K)
    # real(r8), intent(in) :: ha  ! activation energy in photosynthesis temperature function (J/mol)
    #
    ans = np.exp( ha / (rgas*1.e-3*(tfrz+25.)) * (1. - (tfrz+25.)/tl) )
    #
    return ans

def fth_f(tl,hd,se,scaleFactor):
    # From FATES code
    # !
    # !!DESCRIPTION:
    # !photosynthesis temperature inhibition
    # !
    # ! !ARGUMENTS:
    # real(r8), intent(in) :: tl  ! leaf temperature in photosynthesis temp function (K)
    # real(r8), intent(in) :: hd  ! deactivation energy in photosynthesis temp function (J/mol)
    # real(r8), intent(in) :: se  ! entropy term in photosynthesis temp function (J/mol/K)
    # real(r8), intent(in) :: scaleFactor  ! scaling factor for high temp inhibition (25 C = 1.0)
    #
    ans = scaleFactor / ( 1. + np.exp( (-hd+se*tl) / (rgas*1.e-3*tl) ) )
    #
    return ans

def fth25_f(hd,se):
    # From FATES code
    # !
    # !!DESCRIPTION:
    # ! scaling factor for photosynthesis temperature inhibition
    # !
    # ! !ARGUMENTS:
    # real(r8), intent(in) :: hd    ! deactivation energy in photosynthesis temp function (J/mol)
    # real(r8), intent(in) :: se    ! entropy term in photosynthesis temp function (J/mol/K)
    #
    ans = 1. + np.exp( (-hd+se*(tfrz+25.)) / (rgas*1.e-3*(tfrz+25.)) )
    #
    return ans

# %% [markdown]
# # Ingest all the observational trait datasets
#
# #### First the Wright et al trait data for BCI

# %%
wright_bci_traits_filename = 'traits_data/Wright/BCITRAITS_20101220.xls'
wright_bci_traits_file = pandas.read_excel(wright_bci_traits_filename)
wright_bci_traits_file.columns = wright_bci_traits_file.columns.str.replace('$', '')
wright_bci_specieslist = wright_bci_traits_file.loc[:].GENUS + ' ' + wright_bci_traits_file.loc[:].SPECIES
wright_bci_wooddensity1 = np.ma.masked_invalid(np.ma.asarray(wright_bci_traits_file.loc[:].SG100C_AVG))
wright_bci_wooddensity2 = np.ma.masked_invalid(np.ma.asarray(wright_bci_traits_file.loc[:].WSG_CHAVE))
wright_bci_wooddensity = np.ma.column_stack((wright_bci_wooddensity1,wright_bci_wooddensity2)).mean(axis=1)
wright_bci_mortality10cm = np.ma.masked_invalid(np.ma.asarray(wright_bci_traits_file.loc[:].MORT_100))
wright_bci_lma = np.ma.masked_invalid(np.ma.asarray(wright_bci_traits_file.loc[:].LMALEAF_AVD))

# map_funcs.xyplot(wright_bci_wooddensity,wright_bci_lma, dots=True, file='lma_vs_wooddensity', xtitle='wood density', ytitle='LMA')
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %% [markdown]
# #### Ingest the Rogers et al. Leaf vcmax data from the PNM and SLZ crane sites

# %%
rogers_panama_vcmax_filename = 'traits_data/Rogers/2016ENSO_Panama_Fitted_Vcmax_Jmax.xlsx'
rogers_panama_vcmax_file = pandas.read_excel(rogers_panama_vcmax_filename, sheet_name=1)
nrows_rogers_vcmax_file = rogers_panama_vcmax_file.shape[0]

### open table linking species codes to species names from Rogers dataset
rogers_sepciestable_filename = 'traits_data/Rogers/species_code_table.xlsx'
rogers_sepciestable_file = pandas.read_excel(rogers_sepciestable_filename)
rogers_sepciestable_codes = rogers_sepciestable_file.Species_Code[:]
rogers_sepciestable_names = rogers_sepciestable_file.Species_Name[:]
rogers_sepciestable_codes_list = list(rogers_sepciestable_codes)

# create a mapping array that allows us to group observations by species
species_code_list_rogers_vcmaxfile = []
species_name_list_rogers_vcmaxfile = []
species_list_rogers_vcmaxfile_index = np.ma.masked_all(nrows_rogers_vcmax_file)
for i in range(nrows_rogers_vcmax_file):
    species = rogers_panama_vcmax_file.Species[i]
    if not species in species_code_list_rogers_vcmaxfile:
        species_code_list_rogers_vcmaxfile.append(species)
        if species in rogers_sepciestable_codes_list:
            species_name_list_rogers_vcmaxfile.append(rogers_sepciestable_names[rogers_sepciestable_codes_list.index(species)])
        else:
            print(' no species name for code '+species)
            species_name_list_rogers_vcmaxfile.append(species)
    species_list_rogers_vcmaxfile_index[i] = species_code_list_rogers_vcmaxfile.index(species)

nspecies = len(species_code_list_rogers_vcmaxfile)

mean_species_vcmax25 = np.ma.masked_all(nspecies)
#mean_species_vcmax = np.ma.masked_all(nspecies)

### we need temperature scaling factors to get from vcmax to vcmax25
vcmaxha = 65330
vcmaxhd = 149250
vcmaxse = 485
vcmaxc = fth25_f(vcmaxhd, vcmaxse)

# get rid of dots in column header names
rogers_panama_vcmax_file.columns = rogers_panama_vcmax_file.columns.str.replace('.', '')

# sanity check on vcmax temperature scaling
# tleaf = np.linspace(0.,35.,100)
# scalar = (ft1_f(tleaf+tfrz, vcmaxha) * fth_f(tleaf+tfrz, vcmaxhd, vcmaxse, vcmaxc))
# # map_funcs.xyplot(tleaf, scalar)

for i in range(nspecies):
    # extract leaf temeprature and put in K
    veg_tempk = tfrz + np.ma.masked_array(rogers_panama_vcmax_file.MeanTleaf[:], mask = species_list_rogers_vcmaxfile_index != i)
    vcmax25 = np.ma.masked_array(rogers_panama_vcmax_file.Vcmax[:], mask = species_list_rogers_vcmaxfile_index != i) / (ft1_f(veg_tempk, vcmaxha) * fth_f(veg_tempk, vcmaxhd, vcmaxse, vcmaxc))
    mean_species_vcmax25[i] = vcmax25.mean()
    # mean_species_vcmax[i] = np.ma.masked_array(rogers_panama_vcmax_file.Vcmax[:], mask = species_list_rogers_vcmaxfile_index != i).mean()



# ### Ingest Rogers et al LMA data:
# ### actually lets not use these, as they are only for four species...
# rogers_slz_lma_filename = 'traits_data/Rogers/2017_SLZ_LMA_ByAge.xlsx'
# rogers_slz_lma_file = pandas.read_excel(rogers_slz_lma_filename, sheet_name=2)
# nrows_rogers_slz_lma_file = rogers_slz_lma_file.shape[0]
# # create a mapping array that allows us to group observations by species
# species_list_rogers_slafile = []
# species_list_rogers_slafile_index = np.ma.masked_all(nrows_rogers_slz_lma_file)
# for i in range(nrows_rogers_slz_lma_file):
#     species = rogers_slz_lma_file.Species[i]
#     if not species in species_list_rogers_slafile:
#         species_list_rogers_slafile.append(species)
#     species_list_rogers_slafile_index[i] = species_list_rogers_slafile.index(species)
# Out:
#  no species name for code CECRSP

# %% [markdown]
# #### Ingest Norby et al leaf vcmax data from the Panama crane sites

# %%
norby_panama_leaftraits_file = 'traits_data/Norby/Panama_post.xlsx'
norby_panama_leaftraits = pandas.read_excel(norby_panama_leaftraits_file)
norby_panama_leaftraits.columns = norby_panama_leaftraits.columns.str.replace(' ', '')
nrows_norby_panama_leaftraits = norby_panama_leaftraits.shape[0] -1 # ignore the last row of this because they put units in it
norby_panama_vcmax = np.ma.masked_invalid(np.ma.masked_array(norby_panama_leaftraits.Vcmax25[0:nrows_norby_panama_leaftraits], dtype=np.float32))
norby_panama_lma = np.ma.masked_invalid(np.ma.masked_array(norby_panama_leaftraits.LMA[0:nrows_norby_panama_leaftraits], dtype=np.float32))
norby_panama_nmass = np.ma.masked_invalid(np.ma.masked_array(norby_panama_leaftraits.Nmass[0:nrows_norby_panama_leaftraits], dtype=np.float32))
norby_panama_wooddens = np.ma.masked_invalid(np.ma.masked_array(norby_panama_leaftraits.wooddensity[0:nrows_norby_panama_leaftraits], dtype=np.float32))
norby_panama_specieslist = norby_panama_leaftraits.Species

# %% [markdown]
# #### Ingest Wright et al leaf traits database for wet and dry forests at SLZ and PNM

# %%
wright_pnm_slz_leaf_traits_filename = 'traits_data/Wright/LFTRAITS.xlsx'
wright_pnm_slz_leaf_traits_file = pandas.read_excel(wright_pnm_slz_leaf_traits_filename)
wright_pnm_slz_leaf_traits_file.columns = wright_pnm_slz_leaf_traits_file.columns.str.replace('$', '')
wright_pnm_slz_speciescodelist = wright_pnm_slz_leaf_traits_file.SP4
wright_pnm_slz_specieslist = wright_pnm_slz_leaf_traits_file.GENUS + ' ' + wright_pnm_slz_leaf_traits_file.SPECIES
wright_pnm_slz_strata = wright_pnm_slz_leaf_traits_file.STRATA
wright_pnm_slz_iscanopy = np.array(wright_pnm_slz_strata == 'CANOPY', dtype=np.bool)
wright_pnm_slz_lifeform6 = wright_pnm_slz_leaf_traits_file.LIFEFORM6
wright_pnm_slz_istree = np.array(wright_pnm_slz_lifeform6 == 'TREE', dtype=np.bool)
wright_pnm_slz_lifetime = np.ma.masked_invalid(wright_pnm_slz_leaf_traits_file.LIFETIME)
wright_pnm_slz_sla = np.ma.masked_invalid(wright_pnm_slz_leaf_traits_file.SLA_LEAF)
wright_pnm_slz_lma = np.ma.masked_invalid(wright_pnm_slz_leaf_traits_file.LMA)
wright_pnm_slz_npct = np.ma.masked_invalid(wright_pnm_slz_leaf_traits_file.N_PCT)

# %% [markdown]
# #### Ingest Allometry data from Martinez_Cano et al paper

# %%
Martinez_Cano_filename = 'traits_data/Martinez_Cano/MartinezCano_allometry_data_from_article_meansonly.xlsx'
Martinez_Cano_file = pandas.read_excel(Martinez_Cano_filename)
Martinez_Cano_file.columns
#len(Martinez_Cano_file.Species)
# Out:
# Index([u'Species', u'TreeHeight_a', u'TreeHeight_b', u'TreeHeight_k',
#        u'CrownArea_a', u'CrownArea_b'],
#       dtype='object')

# %% [markdown]
# #### now we start to put together the various datasets into a single trait matrix, where we cross-reference all observations by species name, averaging traits where multiple observations exist for a given species.

# %%
master_species_list = []
master_LMA_list = []
master_Narea_list = []
master_wood_density_list = []
master_leaf_lifespan_list = []
master_vcmax25_list = []
master_mortality10cm_list = []
master_crownarea_coefficient_list = []
master_crownarea_exponent_list = []


## start with Wright et al., wet/dry forest data
for i in range(len(wright_pnm_slz_specieslist)):
    if wright_pnm_slz_iscanopy[i] and wright_pnm_slz_istree[i]:
        if not wright_pnm_slz_specieslist[i] in master_species_list:
            master_species_list.append(wright_pnm_slz_specieslist[i])
            master_LMA_list.append([])
            master_Narea_list.append([])
            master_wood_density_list.append([])
            master_leaf_lifespan_list.append([])
            master_vcmax25_list.append([])
            master_mortality10cm_list.append([])
            master_crownarea_coefficient_list.append([])
            master_crownarea_exponent_list.append([])
        indx = master_species_list.index(wright_pnm_slz_specieslist[i])
        if wright_pnm_slz_lma.mask[i] == False:
            master_LMA_list[indx].append(wright_pnm_slz_lma[i])
        if wright_pnm_slz_lifetime.mask[i] == False:
            master_leaf_lifespan_list[indx].append(wright_pnm_slz_lifetime[i])
        if wright_pnm_slz_npct.mask[i] == False:
            master_Narea_list[indx].append(wright_pnm_slz_npct[i] * .01 * wright_pnm_slz_lma[i])

## next add the wright BCI data
for i in range(len(wright_bci_specieslist)):
    if not wright_bci_specieslist[i] in master_species_list:
        master_species_list.append(wright_bci_specieslist[i])
        master_LMA_list.append([])
        master_Narea_list.append([])
        master_wood_density_list.append([])
        master_leaf_lifespan_list.append([])
        master_vcmax25_list.append([])
        master_mortality10cm_list.append([])
        master_crownarea_coefficient_list.append([])
        master_crownarea_exponent_list.append([])
    indx = master_species_list.index(wright_bci_specieslist[i])
    if wright_bci_wooddensity.mask[i] == False:
        master_wood_density_list[indx].append(wright_bci_wooddensity[i])
    if wright_bci_lma.mask[i] == False:
        master_LMA_list[indx].append(wright_bci_lma[i])
    if wright_bci_mortality10cm.mask[i] == False:
        master_mortality10cm_list[indx].append(wright_bci_mortality10cm[i])

## next add the Rogers data
for i in range(len(species_name_list_rogers_vcmaxfile)):
    if not species_name_list_rogers_vcmaxfile[i] in master_species_list:
        master_species_list.append(species_name_list_rogers_vcmaxfile[i])
        master_LMA_list.append([])
        master_Narea_list.append([])
        master_wood_density_list.append([])
        master_leaf_lifespan_list.append([])
        master_vcmax25_list.append([])
        master_mortality10cm_list.append([])
        master_crownarea_coefficient_list.append([])
        master_crownarea_exponent_list.append([])
    indx = master_species_list.index(species_name_list_rogers_vcmaxfile[i])
    if mean_species_vcmax25.mask[i] == False:
        master_vcmax25_list[indx].append(mean_species_vcmax25[i])

## next add the Norby data
for i in range(len(norby_panama_specieslist)-1):  ### they used nan to encode a phantom last species name
    if not norby_panama_specieslist[i] in master_species_list:
        master_species_list.append(norby_panama_specieslist[i])
        master_LMA_list.append([])
        master_Narea_list.append([])
        master_wood_density_list.append([])
        master_leaf_lifespan_list.append([])
        master_vcmax25_list.append([])
        master_mortality10cm_list.append([])
        master_crownarea_coefficient_list.append([])
        master_crownarea_exponent_list.append([])
    indx = master_species_list.index(norby_panama_specieslist[i])
    if norby_panama_vcmax.mask[i] == False:
        master_vcmax25_list[indx].append(norby_panama_vcmax[i])
    if norby_panama_lma.mask[i] == False:
        master_LMA_list[indx].append(norby_panama_lma[i])
    if norby_panama_nmass.mask[i] == False:
        master_Narea_list[indx].append(norby_panama_nmass[i] * .001 * norby_panama_lma[i])
    if norby_panama_wooddens.mask[i] == False:
        master_wood_density_list[indx].append(norby_panama_wooddens[i])

## next add the Martinez-Cano data        
for i in range(len(Martinez_Cano_file.Species)):
    if not Martinez_Cano_file.Species[i] in master_species_list:
        master_species_list.append(Martinez_Cano_file.Species[i])
        master_LMA_list.append([])
        master_Narea_list.append([])
        master_wood_density_list.append([])
        master_leaf_lifespan_list.append([])
        master_vcmax25_list.append([])
        master_mortality10cm_list.append([])
        master_crownarea_coefficient_list.append([])
        master_crownarea_exponent_list.append([])
    indx = master_species_list.index(Martinez_Cano_file.Species[i])
    master_crownarea_coefficient_list[indx].append(Martinez_Cano_file.CrownArea_a[i])
    master_crownarea_exponent_list[indx].append(Martinez_Cano_file.CrownArea_b[i])




### there are a couple artifacts to sort out still: 'Apeiba membranaceae' vs 'Apeiba membranacea'; 'Cojoba rufescens ' vs 'Cojoba rufescens', etc...
nspecies_master = len(master_species_list)
master_LMA_array = np.ma.masked_all(nspecies_master)
master_Narea_array = np.ma.masked_all(nspecies_master)
master_wood_density_array = np.ma.masked_all(nspecies_master)
master_leaf_lifespan_array = np.ma.masked_all(nspecies_master)
master_vcmax25_array = np.ma.masked_all(nspecies_master)
master_mort10cm_array = np.ma.masked_all(nspecies_master)
master_crownarea_coefficient_array = np.ma.masked_all(nspecies_master)
master_crownarea_exponent_array = np.ma.masked_all(nspecies_master)
for i in range(nspecies_master):
    if len(master_vcmax25_list[i]) > 0:
        master_vcmax25_array[i] = np.ma.masked_invalid(np.asarray(master_vcmax25_list[i]).mean()).flatten()
    if len(master_wood_density_list[i]) > 0:
        master_wood_density_array[i] = np.ma.masked_invalid(np.asarray(master_wood_density_list[i]).mean()).flatten()
    if len(master_LMA_list[i]) > 0:
        master_LMA_array[i] = np.ma.masked_invalid(np.asarray(master_LMA_list[i]).mean()).flatten()
    if len(master_Narea_list[i]) > 0:
        master_Narea_array[i] = np.ma.masked_invalid(np.asarray(master_Narea_list[i]).mean()).flatten()
    if len(master_leaf_lifespan_list[i]) > 0:
        master_leaf_lifespan_array[i] = np.ma.masked_invalid(np.asarray(master_leaf_lifespan_list[i]).mean()).flatten()     
    if len(master_mortality10cm_list[i]) > 0:
        master_mort10cm_array[i] = np.ma.masked_invalid(np.asarray(master_mortality10cm_list[i]).mean()).flatten()     
    if len(master_crownarea_coefficient_list[i]) > 0:
        master_crownarea_coefficient_array[i] = np.ma.masked_invalid(np.asarray(master_crownarea_coefficient_list[i]).mean()).flatten()     
    if len(master_crownarea_exponent_list[i]) > 0:
        master_crownarea_exponent_array[i] = np.ma.masked_invalid(np.asarray(master_crownarea_exponent_list[i]).mean()).flatten()     




master_LMA_array = master_LMA_array.flatten()
master_Narea_array = master_Narea_array.flatten()
master_wood_density_array = master_wood_density_array.flatten()
master_leaf_lifespan_array = master_leaf_lifespan_array.flatten()
master_vcmax25_array = master_vcmax25_array.flatten()
master_mort10cm_array = master_mort10cm_array.flatten()
master_crownarea_coefficient_array = master_crownarea_coefficient_array.flatten()
master_crownarea_exponent_array = master_crownarea_exponent_array.flatten()

# map_funcs.xyplot(master_LMA_array, master_leaf_lifespan_array, dots=True, xtitle='LMA', ytitle='leaf lifespan')
# map_funcs.xyplot(master_Narea_array, master_vcmax25_array, dots=True, xtitle='N per unit area', ytitle='vcmax')
# map_funcs.xyplot(master_wood_density_array, master_vcmax25_array, dots=True, xtitle='wood density', ytitle='vcmax')
# map_funcs.xyplot(master_wood_density_array, master_LMA_array, dots=True, xtitle='wood density', ytitle='LMA')


traits_matrix = np.ma.column_stack([master_vcmax25_array,master_wood_density_array,master_LMA_array,master_Narea_array,master_leaf_lifespan_array,master_mort10cm_array,master_crownarea_coefficient_array,master_crownarea_exponent_array,])
traits_matrix = np.ma.masked_invalid(traits_matrix)


column_names = ['Vcmax25', 'wood_density', 'LMA', 'N/area','lifespan','mortality','CrownArea_coef','CrownArea_exp']
df = pandas.DataFrame(traits_matrix, columns=column_names)
# Out:
# /Users/cdkoven/miniconda2/lib/python2.7/site-packages/numpy/core/numeric.py:492: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# #### Next we calculate a covariance matrix for the above

# %%
trait_cov = df.cov()
trait_cov
# Out:
#                     Vcmax25  wood_density          LMA     N/area  \
# Vcmax25          616.837563     -1.427442   399.679850   9.308902
# wood_density      -1.427442      0.021709     0.734569  -0.019823
# LMA              399.679850      0.734569   952.394759  15.044990
# N/area             9.308902     -0.019823    15.044990   0.352939
# lifespan       -2275.126519      4.561589  1591.950432 -11.232024
# mortality         -0.468932     -0.105272   -13.539449   0.027366
# CrownArea_coef    -1.738784      0.003516    -1.110529  -0.030828
# CrownArea_exp      1.100464      0.001088     0.473155   0.008003
#
#                     lifespan  mortality  CrownArea_coef  CrownArea_exp
# Vcmax25         -2275.126519  -0.468932       -1.738784       1.100464
# wood_density        4.561589  -0.105272        0.003516       0.001088
# LMA              1591.950432 -13.539449       -1.110529       0.473155
# N/area            -11.232024   0.027366       -0.030828       0.008003
# lifespan        23903.460405   1.238443       -3.557592       1.240788
# mortality           1.238443  10.267118       -0.004373       0.006367
# CrownArea_coef     -3.557592  -0.004373        0.034595      -0.011395
# CrownArea_exp       1.240788   0.006367       -0.011395       0.007634

# %% [markdown]
# #### Plot the Trait covariance matrix as a series of pair-wise plots.

# %%
pandas.plotting.scatter_matrix(df, alpha=0.7, figsize=(15, 15), diagonal='hist')

#sns.pairplot(df, figsize=(15, 15), diagonal='hist')
# try seaborn version of scatter_matrix (gives error though, so sticking with pandas version)
#g = sns.pairplot(df)
#print(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b84e990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b7b1650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d880410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d8bb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d8e9f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d924d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d95bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d99f0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d9d5290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11da0e450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11da44610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11da7b7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dab3990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11daeab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11db22d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11db5aed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11db9e0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dbd6290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dc0e450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dc45610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dc7c7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dcb3990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dceab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dd23d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11dd5bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dd9d0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ddd4290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11de0b450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11de42610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11de7a7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11deb2990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11deebb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11df22d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11df5bed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11df9d0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dfbbd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dff0f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e032110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e06c2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e0a3490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e0dc650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e114810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e14c9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e185b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e1bdd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e1f9f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e23b110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2732d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e2ab490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2e4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e31d810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e3549d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e38bb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e3c6d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e3fff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e442110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e47a2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e4b6490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e4ed650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e524810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e55d9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e596b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e5cfd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e606f10>]],
#       dtype=object)

# %% [markdown]
# #### Calculate a synthetic traits dataset where we assume that some of the traits are normally distributed, and some of them are lognormally distributed.

# %%
n_out = 287
randomstate = np.random.RandomState(11)


### because of the large amount of missing data in the above, sample as a random draw from the trait
### covariance matrix instead, so that we can generate a large number of trait values to use for a FATES ensemble.
## we will actually skip this for now, so as to work with the partially-log-transformed dataset
#means = traits_matrix.mean(axis=0)
#X = randomstate.multivariate_normal(means, np.array(trait_cov), n_out)
#df2 = pandas.DataFrame(X, columns=column_names)
#pandas.plotting.scatter_matrix(df2, alpha=0.7, figsize=(15, 15), diagonal='hist')


### instead of doing the above on raw trait data, try defining covariance matrix off of log-transformed trait data for all traits
## we will actually skip this too, so as to work with the partially-log-transformed dataset
#log_traits_matrix = np.ma.log(traits_matrix)
#log_cov = np.ma.cov(log_traits_matrix.transpose())
#log_means = log_traits_matrix.mean(axis=0)
#X_log = np.exp(randomstate.multivariate_normal(log_means, np.array(log_cov), n_out))
#df3 = pandas.DataFrame(X_log, columns=column_names)
#pandas.plotting.scatter_matrix(df3, alpha=0.7, figsize=(15, 15), diagonal='hist')


### what we really want to do is treat some variables as normal and others as lognormal. 
### e.g. mortality is clearly not normally distributed.

partially_log_traits_matrix = traits_matrix.copy()

#print(partially_log_traits_matrix.shape)

## for now, assume that mortality and LMA are both lognormally distributed and define covariance matrix accordingly
columns_log = [2,5]
for i in range(len(columns_log)):
    partially_log_traits_matrix[:,columns_log[i]] = np.ma.log(partially_log_traits_matrix[:,columns_log[i]])

partially_log_cov = np.ma.cov(partially_log_traits_matrix.transpose())
partially_log_means = partially_log_traits_matrix.mean(axis=0)
X_partially_log = randomstate.multivariate_normal(partially_log_means, np.array(partially_log_cov), n_out)

for i in range(len(columns_log)):
    X_partially_log[:,columns_log[i]] = np.exp(X_partially_log[:,columns_log[i]])

df4 = pandas.DataFrame(X_partially_log, columns=column_names)
pandas.plotting.scatter_matrix(df4, alpha=0.7, figsize=(15, 15), diagonal='hist')
# Out:
# /Users/cdkoven/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: covariance is not positive-semidefinite.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f0b2810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f06a410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f150310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f3a1250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109b2a410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109b655d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f3c3790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f3f7590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f42e750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f466910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f49fad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f4d7c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f50ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f552050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f58b210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5c53d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f5fd590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f636750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f66eb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6a6ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6ddc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f715e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f75a050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f791210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f7cd3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f804590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f83d750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f873910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f8acad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f8e5c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f91ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f964050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f99d210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f9d53d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa0e590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa45750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fa7d910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fab5ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11faedc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fb25e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fb6c050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fba4210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fbdc3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc14590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc4d750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fc84910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fcbcad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fcf6c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fd2fe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fd73050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fdad210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fde53d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe1c590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe56750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe8e910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fec4ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11fefec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff38e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ff7b050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ffb5210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ffee3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120025590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12005c750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120095910>]],
#       dtype=object)

# %% [markdown]
# #### Now we'd like to add a few other traits to the mix, even though we don't have observations of all of what we want.  THe choice here is somewhat arbitrary, but we are focusing on some allometric parameters that we know to be important in governing the plant carbon economics.

# %%
### these next sets of trait distributions are all completely made up.  

bleaf_to_dbh_mean = 0.2
bleaf_to_dbh_variance = (0.05)**2
bleaf_to_dbh_indx = 8

fineroot_to_leaf_mean = 0.7
fineroot_to_leaf_variance = (0.15)**2
fineroot_to_leaf_indx = 9

bbslope_mean = 8.
bbslope_variance = (2.)**2
bbslope_indx = 10

latosa_mean = 0.3
latosa_variance = 0.20 ** 2
latosa_indx = 11

ntraits_total = 12
full_trait_cov_matrix = np.zeros([ntraits_total,ntraits_total])

# we are using the partially log-transformed traits covariance matrix now
full_trait_cov_matrix[0:8,0:8] = partially_log_cov[:]

#full_trait_cov_matrix[mortality_indx,mortality_indx] = mortality_variance
full_trait_cov_matrix[bleaf_to_dbh_indx,bleaf_to_dbh_indx] = bleaf_to_dbh_variance
full_trait_cov_matrix[fineroot_to_leaf_indx,fineroot_to_leaf_indx] = fineroot_to_leaf_variance
full_trait_cov_matrix[bbslope_indx,bbslope_indx] = bbslope_variance
full_trait_cov_matrix[latosa_indx,latosa_indx] = latosa_variance


means_total = np.zeros(ntraits_total)
# we are using the partially log-transformed traits covariance matrix now
means_total[0:8] = partially_log_means[:]

means_total[bleaf_to_dbh_indx] = bleaf_to_dbh_mean
means_total[fineroot_to_leaf_indx] = fineroot_to_leaf_mean
means_total[bbslope_indx] = bbslope_mean
means_total[latosa_indx] = latosa_mean

X_total = randomstate.multivariate_normal(means_total, np.array(full_trait_cov_matrix), n_out)
X_total_backup = randomstate.multivariate_normal(means_total, np.array(full_trait_cov_matrix), n_out)

#since we have log-transformed some of the traits data, need to get back to raw values
for i in range(len(columns_log)):
    X_total[:,columns_log[i]] = np.exp(X_total[:,columns_log[i]])
    X_total_backup[:,columns_log[i]] = np.exp(X_total_backup[:,columns_log[i]])


### all of these variables are positive definite.  go through them and check each row to make sure that all values
### in the row are positive.  if not, replace the entire row with one from a backup array
backup_copy = -1
for i in range(n_out):
    if X_total[i,:].min() <= 0:
        replacement_found = False
        backup_copy = backup_copy + 1
        while not replacement_found:
            if X_total_backup[backup_copy,:].min() > 0:
                replacement_found = True
            else:
                backup_copy = backup_copy + 1
        X_total[i,:] = X_total_backup[backup_copy,:]
column_names_full = ['Vcmax25', 'wood_density', 'LMA', 'N/area','lifespan','mortality','crown_dbh_coef','crown_dbh_exp','bleaf_dbh','fineroot_leaf','BB_slope','LATOSA']
df4 = pandas.DataFrame(X_total, columns=column_names_full)
pandas.plotting.scatter_matrix(df4, alpha=0.7, figsize=(25, 25), diagonal='hist')
# Out:
# /Users/cdkoven/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:63: RuntimeWarning: covariance is not positive-semidefinite.
# /Users/cdkoven/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:64: RuntimeWarning: covariance is not positive-semidefinite.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116817a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116b8bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116b95cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116c1ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171dfe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f2f3090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116bb2250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11723b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172745d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172ad790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172e5950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11731db10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117353cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11738be90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1173cd090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117408250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11743f410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11747a5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1174b3790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1174eb950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117522b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11755acd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117593e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1175d6090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11760e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11764a410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176827d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176b8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176f1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117729b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117762cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117799e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1177e0090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117818250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117850410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11788a5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1178c2790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1178f9950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117930b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11796acd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179a3e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179e7090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a20250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a58410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a905d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ac9790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b00950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b38b10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117b71cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117bade90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117bf0090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c28250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c60410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c985d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ccf790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d08950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d42b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d7bcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117db4e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117df7090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117e2e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e67410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ea25d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ed9790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f12950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f49b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f82cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117fb7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ff1d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11802af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11806e110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1180a52d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1180dd490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118115650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11814f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1181879d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1181c0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1181f8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118230f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118274110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1182ad2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1182e5490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11831d650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118358810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1183909d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1183c7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118400d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118439f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11847d110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1184b62d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1184ef490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118527650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11855f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1185989d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1185cfb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118608d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118642f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118686110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186be2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186f6490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118730650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118767810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11879f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1187d7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118810d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118848f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11888d110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1188c52d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1188ff490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118937650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11896f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1189a99d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1189e1b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a1ad50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a52f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a96110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ace2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b08490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b3f650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b77810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118bb19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118be9b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c22d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c59f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c9f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118cd72d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d10490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d49650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d81810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118db89d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118df1b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118e28d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118e61f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ea8110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ee12d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f18490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f51650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f89810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118fc09d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ff8b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119032d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11906af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1190b0110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1190e72d0>]],
#       dtype=object)

# %% [markdown]
# #### now we want to write this full set of parameters to a set of fates netcdf parameter files, which we'll use to generate an ensemble of FATES runs.

# %%
### 
import netCDF4 as nc4
import sys
import os
import shutil

print(X_total.shape)

def copy_clobber(filename1, filename2):
    try:
        os.remove(filename2)
        print('replacing file: '+filename2)
    except:
        print('file does not yet exist: '+filename2)
    shutil.copyfile(filename1, filename2)

vcmax25_indx = 0
wood_density_indx = 1
lma_indx = 2
n_area_indx = 3
lifespan_indx = 4
mortality_indx = 5

carbon_fraction_mean = .4482  ## mean of leaf samples in norby dataset

#print(carbon_fraction_mean * X_total[:,lma_indx] / X_total[:,n_area_indx])  #sanity check for leafcn
#print(1./X_total[:,lma_indx]) #sanity check for lma
#print(X_total[:,lifespan_indx]/365.25) #sanity check for leaf lifespan
#sys.exit()

#filename_template = 'fates_parameter_files/fates_params_default_c6ff126_mod4.nc'
filename_template = 'fates_parameter_files/fates_params_default_770ac36_mod.nc'
filename_output_basename = 'fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_'
for i in range(n_out):
    filename_out = filename_output_basename+str(i+1).zfill(4)+'.c180821.nc'
    copy_clobber(filename_template,filename_out)
    fin = nc4.Dataset(filename_out, 'r+')
    #
    vcmax25var = fin.variables['fates_leaf_vcmax25top']
    vcmax25var[:] = X_total[i,vcmax25_indx]
    #
    wood_density_var = fin.variables['fates_wood_density']
    wood_density_var[:] = X_total[i,wood_density_indx]
    #
    slatopvar = fin.variables['fates_leaf_slatop']
    slatopvar[:] = 1./(X_total[i,lma_indx] * carbon_fraction_mean)
    #
    leafcnvar = fin.variables['fates_leaf_cn_ratio']
    leafcnvar[:] = carbon_fraction_mean * X_total[i,lma_indx] / X_total[i,n_area_indx]
    #
    leaflongvar = fin.variables['fates_leaf_long']
    leaflongvar[:] = X_total[i,lifespan_indx]/365.25
    #
    bmortvar = fin.variables['fates_mort_bmort']
    bmortvar[:] = X_total[i,mortality_indx] * 1e-2
    #
    crown_to_dbh_coef_var1 = fin.variables['fates_allom_d2ca_coefficient_min']
    crown_to_dbh_coef_var2 = fin.variables['fates_allom_d2ca_coefficient_max']
    crown_to_dbh_coef_var1[:] = X_total[i,crown_to_dbh_coef_indx]
    crown_to_dbh_coef_var2[:] = X_total[i,crown_to_dbh_coef_indx]
    #
    crown_to_dbh_exponent_var = fin.variables['fates_allom_d2bl2']
    crown_to_dbh_exponent_var[:] = X_total[i,crown_to_dbh_exponent_indx]
    #
    bleaf_to_dbh_var = fin.variables['fates_allom_d2bl1']
    bleaf_to_dbh_var[:] = X_total[i,bleaf_to_dbh_indx]
    #
    fineroot_to_leaf_var = fin.variables['fates_allom_l2fr']
    fineroot_to_leaf_var[:] = X_total[i,fineroot_to_leaf_indx]
    #
    bbslopevar = fin.variables['fates_leaf_BB_slope']
    bbslopevar[:] = X_total[i,bbslope_indx]
    #
    latosavar = fin.variables['fates_allom_latosa_int']
    latosavar[:] = X_total[i,latosa_indx]
    #
    fin.close()
# Out:
# (287, 12)
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0001.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0002.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0003.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0004.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0005.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0006.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0007.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0008.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0009.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0010.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0011.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0012.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0013.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0014.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0015.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0016.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0017.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0018.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0019.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0020.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0021.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0022.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0023.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0024.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0025.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0026.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0027.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0028.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0029.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0030.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0031.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0032.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0033.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0034.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0035.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0036.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0037.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0038.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0039.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0040.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0041.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0042.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0043.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0044.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0045.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0046.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0047.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0048.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0049.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0050.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0051.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0052.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0053.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0054.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0055.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0056.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0057.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0058.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0059.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0060.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0061.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0062.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0063.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0064.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0065.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0066.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0067.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0068.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0069.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0070.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0071.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0072.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0073.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0074.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0075.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0076.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0077.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0078.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0079.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0080.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0081.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0082.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0083.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0084.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0085.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0086.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0087.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0088.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0089.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0090.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0091.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0092.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0093.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0094.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0095.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0096.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0097.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0098.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0099.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0100.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0101.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0102.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0103.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0104.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0105.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0106.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0107.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0108.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0109.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0110.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0111.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0112.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0113.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0114.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0115.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0116.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0117.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0118.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0119.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0120.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0121.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0122.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0123.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0124.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0125.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0126.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0127.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0128.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0129.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0130.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0131.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0132.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0133.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0134.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0135.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0136.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0137.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0138.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0139.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0140.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0141.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0142.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0143.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0144.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0145.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0146.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0147.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0148.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0149.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0150.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0151.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0152.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0153.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0154.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0155.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0156.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0157.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0158.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0159.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0160.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0161.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0162.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0163.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0164.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0165.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0166.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0167.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0168.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0169.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0170.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0171.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0172.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0173.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0174.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0175.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0176.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0177.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0178.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0179.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0180.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0181.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0182.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0183.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0184.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0185.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0186.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0187.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0188.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0189.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0190.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0191.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0192.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0193.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0194.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0195.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0196.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0197.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0198.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0199.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0200.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0201.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0202.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0203.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0204.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0205.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0206.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0207.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0208.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0209.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0210.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0211.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0212.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0213.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0214.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0215.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0216.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0217.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0218.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0219.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0220.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0221.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0222.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0223.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0224.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0225.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0226.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0227.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0228.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0229.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0230.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0231.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0232.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0233.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0234.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0235.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0236.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0237.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0238.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0239.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0240.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0241.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0242.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0243.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0244.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0245.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0246.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0247.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0248.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0249.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0250.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0251.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0252.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0253.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0254.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0255.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0256.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0257.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0258.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0259.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0260.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0261.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0262.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0263.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0264.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0265.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0266.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0267.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0268.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0269.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0270.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0271.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0272.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0273.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0274.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0275.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0276.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0277.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0278.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0279.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0280.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0281.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0282.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0283.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0284.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0285.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0286.c180717.nc
# file does not yet exist: fates_parameter_files/fates_params_770ac36_bcitraits_test01_v_0287.c180717.nc

# %% [markdown]
# #### write the raw trait matrix out as a text file for easy analysis. of outputs against trait values.

# %%
print(X_total.shape)
#files_used_start = 0
#files_used_end = n_out
#print(X_total[files_used_start:files_used_end].shape)
#np.savetxt('traits_matrix_used_in_param_files_240518.txt', X_total[files_used_start:files_used_end])
#np.savetxt('traits_matrix_used_in_param_files_180525.txt', X_total)
#np.savetxt('traits_matrix_used_in_param_files_180529.txt', X_total)
#np.savetxt('traits_matrix_used_in_param_files_180531.txt', X_total)
#np.savetxt('traits_matrix_used_in_param_files_180604.txt', X_total)
#np.savetxt('traits_matrix_used_in_param_files_180605.txt', X_total)
np.savetxt('traits_matrix_used_in_param_files_180821.txt', X_total)
# Out:
# (287, 12)

# %%
#### try a new matrix where we set the leaf traits to mean values, 
###  and instead vary a larger set of allocation traits

## traits to set as mean: vcmax, SLA, leaf lifespan, N/area, background mortality
## wood density, bb_slope

## increase range of crown:dbh coef, fineroot_leaf, d2bl1
